# %%
import numpy as np



word_dict = {}
with open('data.txt', 'r') as f:
    for index, line in enumerate(f):
        word, freq = line.strip().split()
        word_dict[word] = (index, int(freq))    

import itertools

with open('wiki-out.txt', 'r') as f:
    while True:
        lines = list(itertools.islice(f, 3))
        if not lines:
            break
        # 处理这三行
        for line in lines:
            print(line.strip())

index, freq = word_dict[word]
